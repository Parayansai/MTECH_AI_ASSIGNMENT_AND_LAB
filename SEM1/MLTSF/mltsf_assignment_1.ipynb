# %% [markdown]
# # moving average filter

# %%
''' a teacher demanded on of his student to bring an average of 10kg ladoos every week to distribute in the class but the teachers mood per 
week is erratic or unpredictible , the teacher is almost never satisfied by the amount of ladoos the student brings so the student has to adjust 
the amounnt every week such that the mean stays centered around 10kg'''

# %%
''' let j be the cost , error variable is the teachers mood, alpha is the acceptance rate of the change in error '''

# %%
import matplotlib.pyplot as plt

# %%
error=[]
for i in range(100):
    error.append(random.randint(-3,3))
print(error)
# Out:
# [2, 1, -2, -2, -3, 0, 1, 1, -3, 3, -2, 3, -1, 2, 3, -2, 0, -1, 2, 0, 3, 1, 0, -1, 0, -2, -3, 1, 3, -3, 2, -1, 0, 1, -3, -2, 1, -1, 2, -1, 2, -3, -3, 2, 0, -3, -3, 2, 2, -3, 2, 0, -1, -1, 0, 2, -1, -1, 0, -1, -3, -3, 2, -2, 2, -1, 1, -3, -2, -3, -3, -1, -1, -1, 1, 2, 2, 0, 2, 3, 1, -2, 2, -2, -3, -3, -2, 1, 2, 2, -2, 2, 3, -1, 1, -1, -2, 3, -3, -2]

# %%
import random
alpha=0.5 #
mean=10
values=[]
for i in range(60):
    #error = random.randint(-3,3)
    j=mean-alpha*(error[i])
    values.append(j)
    print(j)
# Out:
# 9.0
# 9.5
# 11.0
# 11.0
# 11.5
# 10.0
# 9.5
# 9.5
# 11.5
# 8.5
# 11.0
# 8.5
# 10.5
# 9.0
# 8.5
# 11.0
# 10.0
# 10.5
# 9.0
# 10.0
# 8.5
# 9.5
# 10.0
# 10.5
# 10.0
# 11.0
# 11.5
# 9.5
# 8.5
# 11.5
# 9.0
# 10.5
# 10.0
# 9.5
# 11.5
# 11.0
# 9.5
# 10.5
# 9.0
# 10.5
# 9.0
# 11.5
# 11.5
# 9.0
# 10.0
# 11.5
# 11.5
# 9.0
# 9.0
# 11.5
# 9.0
# 10.0
# 10.5
# 10.5
# 10.0
# 9.0
# 10.5
# 10.5
# 10.0
# 10.5

# %%
#data observed for 30 weeks with acceptance rate as 30 percent
plt.plot(range(1,31),values)
plt.xlabel("week")
plt.ylabel("ladoo amount")
# Out:
# Text(0, 0.5, 'ladoo amount')

# %%
# data observed for 60 weeks with acceptance rate as 30 percent
plt.plot(range(1,61),values)
plt.xlabel("week")
plt.ylabel("ladoo amount")
# Out:
# Text(0, 0.5, 'ladoo amount')

# %%
# data observed for 100 weeks with acceptance rate as 30 percent
plt.plot(range(1,101),values)
plt.xlabel("week")
plt.ylabel("ladoo amount")
# Out:
# Text(0, 0.5, 'ladoo amount')

# %%
# data observed for 30 weeks with acceptance rate as 50 percent
plt.plot(range(1,31),values)
plt.xlabel("week")
plt.ylabel("ladoo amount")
# Out:
# Text(0, 0.5, 'ladoo amount')

# %%
# data observed for 60 weeks with acceptance rate as 50 percent
plt.plot(range(1,61),values)
plt.xlabel("week")
plt.ylabel("ladoo amount")
# Out:
# Text(0, 0.5, 'ladoo amount')
